# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("smart irrigation.csv")

# %%
dataset
# Out:
#       farm_id  soil_moisture_%  temperature_C  humidity_%  soil_score  \
# 0    FARM0001            35.95          17.79       77.03      0.6405
# 1    FARM0002            19.74          30.18       61.13      0.8026
# 2    FARM0003            29.32          27.37       68.87      0.7068
# 3    FARM0004            17.33          33.73       70.46      0.8267
# 4    FARM0005            19.37          33.86       55.73      0.8063
# ..        ...              ...            ...         ...         ...
# 495  FARM0496            42.85          30.85       79.58      0.5715
# 496  FARM0497            34.22          17.46       45.14      0.6578
# 497  FARM0498            15.93          17.03       57.87      0.8407
# 498  FARM0499            38.61          17.08       73.09      0.6139
# 499  FARM0500            30.22          20.57       89.74      0.6978
#
#      temp_score  humidity_Score  round      irrigation
# 0        0.3558          0.2297   0.47  IRRIGATION OFF
# ...

# %% [raw]
# dataset.shape

# %%
dataset.shape
# Out:
# (500, 9)

# %%
print(type(dataset))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dataset.isnull().sum()
# Out:
# farm_id            0
# soil_moisture_%    0
# temperature_C      0
# humidity_%         0
# soil_score         0
# temp_score         0
# humidity_Score     0
# round              0
# irrigation         0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   farm_id          500 non-null    object
#  1   soil_moisture_%  500 non-null    float64
#  2   temperature_C    500 non-null    float64
#  3   humidity_%       500 non-null    float64
#  4   soil_score       500 non-null    float64
#  5   temp_score       500 non-null    float64
#  6   humidity_Score   500 non-null    float64
#  7   round            500 non-null    float64
#  8   irrigation       500 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 35.3+ KB
