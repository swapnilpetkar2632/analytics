# %% [markdown]
# NUMPY

# %%
import numpy as np
import statistics as stats
baked_food = [100,300,400,400,560,432,456,798]
a=np.array(baked_food)

# %%
print(type(baked_food))
# Out:
# <class 'list'>

# %%
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
print(np.mean(a))
# Out:
# 430.75

# %%
print(np.median(a))
# Out:
# 416.0

# %%
print(stats.mode(a))
# Out:
# 400

# %% [raw]
# print(np.std(a))

# %%
print(np.std(a))
# Out:
# 187.28304114361237

# %%
print(np.var(a))
# Out:
# 35074.9375

# %%
187.28304114361237**2
# Out:
# 35074.9375

# %%
import numpy as np

tobacco = [23, 23, 45, 56, 70, 80, 55]
death   = [100, 340, 200, 530, 444, 543]
ab=np.array(tobacco)
b=np.array(death)

s = np.corrcoef([ab,b])
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 8
#       5 ab=np.array(tobacco)
#       6 b=np.array(death)
# ----> 8 s = np.corrcoef([ab,b])
#       9 print(s)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:3037, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    3033 if bias is not np._NoValue or ddof is not np._NoValue:
#    3034     # 2015-03-15, 1.10
#    3035     warnings.warn('bias and ddof have no effect and are deprecated',
#    3036                   DeprecationWarning, stacklevel=2)
# -> 3037 c = cov(x, y, rowvar, dtype=dtype)
#    3038 try:
#    3039     d = diag(c)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:2805, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2801     raise ValueError(
# ...
