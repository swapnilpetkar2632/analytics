# %% [raw]
# # slising of string

# %%
a = "game of throns "
print(a)
# Out:
# game of throns

# %%
print (a[0:5])
# Out:
# game

# %%
print(a[-5:])
# Out:
# rons

# %%
print(a[::2])
# Out:
# gm ftrn

# %%
print(a[:7:2])
# Out:
# gm f

# %%
print(a[::-1])
# Out:
#  snorht fo emag
