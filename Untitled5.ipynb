# %%
import numpy as np
arr = np.array([[10,20,30,40],[10,20,30,40]])
print(arr)
# Out:
# [[10 20 30 40]
#  [10 20 30 40]]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(len(arr))
# Out:
# 2

# %%
print(np.size(arr))
# Out:
# 8

# %%
print(arr.dtype)
# Out:
# int64

# %%
print(arr.astype(str))
# Out:
# [['10' '20' '30' '40']
#  ['10' '20' '30' '40']]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>
