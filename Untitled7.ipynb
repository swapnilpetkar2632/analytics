# %%
import pandas as pd

# %%
dict={"keys":["k1","k2","k1","k2"],
     "names":["john","doe","jane","smith"],
       "houses":["red","blue","green","red"],
       "grades":["3rd","4th","3rd","4th"]}
df=pd.DataFrame(dict)
print(df)
# Out:
#   keys  names houses grades
# 0   k1   john    red    3rd
# 1   k2    doe   blue    4th
# 2   k1   jane  green    3rd
# 3   k2  smith    red    4th

# %%
print(pd.melt(df, id_vars=["names"], value_vars=["houses"]))
# Out:
#    names variable  value
# 0   john   houses    red
# 1    doe   houses   blue
# 2   jane   houses  green
# 3  smith   houses    red

# %%
df.pivot(index="keys", columns="names", values=["house", "grade"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.pivot(index="keys", columns="names", values=["house", "grade"])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# -> 9339     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\pivot.py:563, in pivot(data, columns, index, values)
#     559 if is_list_like(values) and not isinstance(values, tuple):
# ...
