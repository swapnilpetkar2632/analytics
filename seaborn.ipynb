# %%
import seaborn as sns
import  pandas as pd
import matplotlib.pyplot as plt

# %%
data={"day":[1,2,3,4,5],
     "nop":[20,40,30,40,70]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    day  nop
# 0    1   20
# 1    2   40
# 2    3   30
# 3    4   40
# 4    5   70

# %%
sns.lineplot(data=data,x="day",y="nop")
# Out:
# <Axes: xlabel='day', ylabel='nop'>

# %%
dff=pd.read_csv("loan.csv")

# %%
dff
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dff=dff.head(50)

# %%
sns.lineplot(data=dff,x="Dependents",y="ApplicantIncome",hue="Education",style="Gender")
# Out:
# <Axes: xlabel='Dependents', ylabel='ApplicantIncome'>

# %%
data=sns.load_dataset("tips")
data
sns.barplot(data=data,x="day",y="tip",hue="sex",palette="spring")
plt.plot()
# Out:
# []

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=data,x="day",hue="sex",kde=True,discrete=True,bins=49)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.scatterplot(data=data,x="total_bill",y="tip",hue="day",palette="viridis",size="size",marker="o")
plt.plot()
# Out:
# []

# %%
import pandas as pd
import os
print(os.getcwd())
# Out:
# C:\Users\Sawpanil\analytics

# %%
import pandas as pd
data1 = pd.read_excel("ESD.xlsx")
print(data.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.heatmap(data.isnull())
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dtt=sns.load_dataset("tips")
gp=dtt.groupby("day").agg({"tip":"sum"})
sns.heatmap(gp)
# Out:
# C:\Users\Sawpanil\AppData\Local\Temp\ipykernel_18068\250670110.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gp=dtt.groupby("day").agg({"tip":"sum"})
# <Axes: ylabel='day'>

# %%
sns.countplot(data=dtt,x="sex",hue="day",palette="viridis")
sns.set_style(style="ticks")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(data=data,x="tip")
# Out:
# <Axes: xlabel='tip'>

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(data=data1,x="Annual Salary")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.violinplot(data=data1,x="Annual Salary",y="size")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:1725, in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1714 def violinplot(
#    1715     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1716     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)   1722     inner_kws=None, ax=None, **kwargs,
#    1723 ):
# -> 1725     p = _CategoricalPlotter(
#    1726         data=data,
# ...

# %%
sns.pairplot(data,hue="day")

# %%
sns.boxplot(data,x="day",y="tip",orient="vertical")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.catplot(data,x="total_bill",y="day",hue="sex",palette="viridis",kind="violin")

# %%
import seaborn as sns

# Example: show the "viridis" palette
sns.palplot(sns.color_palette("viridis"))

# %%
data.info()
sns.relplot(data,x="total_bill",y="tip")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.swarmplot(data,x="day",y="tip",hue="sex",dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
